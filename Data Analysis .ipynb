# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\adity\\Downloads\\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 665   2800-VEQXM  Female              0      No         No       3
# 2991  2207-QPJED  Female              1     Yes         No      37
# 6123  0623-EJQEG    Male              0      No         No      65
# 4284  8189-XRIKE  Female              1      No         No      32
# 6696  4566-NECEV    Male              0      No         No       5
# 3884  4521-YEEHE  Female              0     Yes         No      18
# 2801  1017-FBQMM  Female              0     Yes        Yes      62
# 4537  1100-DDVRV    Male              0     Yes         No      17
# 4167  5120-ZBLAI  Female              0     Yes         No      50
# 5313  1935-IMVBB    Male              0     Yes         No      56
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 665           Yes                No     Fiber optic             No  ...
# 2991          Yes                No     Fiber optic             No  ...
# ...

# %% [markdown]
# OUT OF ALL CUSTOMERS WHAT IS THE CHURN RATE FOR MALE AND FEMALE?

# %%
sns.countplot(x="gender", hue="Churn", data=df)
plt.show()

# %% [markdown]
# WHICH CUSTOMER HAS MORE TENURE MALE OR FEMALE?

# %%
sns.barplot(x="tenure",y="gender",data=df)
plt.show()

# %% [markdown]
# Which Internet service provider has highest ratio?

# %%
sns.countplot(x="InternetService",data=df)
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %% [markdown]
# out of all customers howmuch male or female customer undergoes senior citizen category?

# %%
sns.countplot(x="SeniorCitizen",hue="gender",data=df)
plt.show()

# %% [markdown]
# which has high tenure rate having partner or not having partner?

# %%
sns.countplot(x="Partner",hue="tenure",data=df)
plt.show()

# %% [markdown]
# which has highest ratio of all payment modes?

# %%
df["PaymentMethod"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.show()

# %%
plt.hist(df["tenure"])
plt.show()

# %%
df["MonthlyCharges"].min()
# Out:
# np.float64(18.25)

# %%
sns.scatterplot(x="TotalCharges",y="MonthlyCharges",data=df.head(10))
plt.show()

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.show()
